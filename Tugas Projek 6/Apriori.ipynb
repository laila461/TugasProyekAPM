1,0,3,1\r\nSTR122,Apparel Zone,Apparel,Mumbai,15.5,80,318,150,2.76,3.52,16.87,0,0,3,2\r\nSTR123,Fashion Bazar,Apparel,Mumbai,15.2,80,304,150,3.15,3.435,17.3,0,0,3,2\r\nSTR124,Digital Bazar,Electronincs,Mumbai,13.3,80,350,245,3.73,3.84,15.41,0,0,3,4\r\nSTR125,Electronics Zone,Electronincs,Kolkata,19.2,80,400,175,3.08,3.845,17.05,0,0,3,2\r\nSTR126,Apparel Zone,Apparel,Kolkata,27.3,40,79,66,4.08,1.935,18.9,1,1,4,1\r\nSTR127,Super Bazar,Super Market,Kolkata,26,40,120.3,91,4.43,2.14,16.7,0,1,5,2\r\nSTR128,Super Market,Super Market,Kolkata,30.4,40,95.1,113,3.77,1.513,16.9,1,1,5,2\r\nSTR129,Central Store,Super Market,Kolkata,15.8,80,351,264,4.22,3.17,14.5,0,1,5,4\r\nSTR130,Apparel Zone,Apparel,Kolkata,19.7,60,145,175,3.62,2.77,15.5,0,1,5,4\r\nSTR131,Fashion Bazar,Apparel,Kolkata,15,80,301,335,3.54,3.57,14.6,0,1,5,4\r\nSTR132,Digital Bazar,Electronincs,Kolkata,21.4,40,121,109,4.11,2.78,18.6,1,1,4,2\r\n'}

# %%
stores = pd.read_csv('stores.csv', header=None)
stores.head()
# Out:
#           0                 1             2         3              4   \
# 0  StoreCode         StoreName     StoreType  Location  OperatingCost
# 1     STR101  Electronics Zone  Electronincs     Delhi             21
# 2     STR102      Apparel Zone       Apparel     Delhi             21
# 3     STR103       Super Bazar  Super Market     Delhi           22.8
# 4     STR104      Super Market  Super Market     Delhi           21.4
#
#           5           6                7               8           9   \
# 0  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize
# 1         60         160              110             3.9        2.62
# 2         60         160              110             3.9       2.875
# 3         40         108               93            3.85        2.32
# 4         60         258              110            3.08       3.215
#
#               10        11              12      13            14
# 0  ProfitPercust  OwnStore  OnlinePresence  Tenure  StoreSegment
# 1          16.46         0               1       4             4
# 2          17.02         0               1       4             4
# 3          18.61         1               1       4             1
# 4          19.44         1               0       3             1

# %%
records = []
for i in range(0, 32):
    records.append([str(stores.values[i,j]) for j in range(0, 15)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print(len(association_results))

# %%
print(association_results[0])

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
