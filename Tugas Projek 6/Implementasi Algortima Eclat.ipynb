# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in d:\annaconda\lib\site-packages (1.1.2)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:/Annaconda/data/groceries.csv', header = None)
transact_list = [] 
for i in range(0, 7501):
  transact_list.append([str(data.values[i,j]) for j in range(0, 20)])
data.head()
# Out:
#             0        1               2             3             4       5   \
# 0        udang   almond         alpukat       sayuran  anggur hijau  gandum
# 1       burger    bakso           telur           NaN           NaN     NaN
# 2  kacang mete      NaN             NaN           NaN           NaN     NaN
# 3        bebek  alpukat             NaN           NaN           NaN     NaN
# 4  air mineral     susu  snack batangan  tepung beras     teh hijau     NaN
#
#      6             7                  8          9            10         11  \
# 0  ragi  keju kemasan  minuman berenergi  jus tomat  susu yogurt  teh hijau
# 1   NaN           NaN                NaN        NaN          NaN        NaN
# 2   NaN           NaN                NaN        NaN          NaN        NaN
# 3   NaN           NaN                NaN        NaN          NaN        NaN
# 4   NaN           NaN                NaN        NaN          NaN        NaN
#
#      12     13           14      15                  16            17     18  \
# 0  madu  salad  air mineral  salmon  minuman bervitamin  minuman rasa  bayam
# 1   NaN    NaN          NaN     NaN                 NaN           NaN    NaN
# 2   NaN    NaN          NaN     NaN                 NaN           NaN    NaN
# 3   NaN    NaN          NaN     NaN                 NaN           NaN    NaN
# 4   NaN    NaN          NaN     NaN                 NaN           NaN    NaN
#
#               19
# 0  minyak zaitun
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
from apyori import apriori
rules = apriori(transactions = transact_list, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %%
rslt = list(rules)
rslt
# Out:
# [RelationRecord(items=frozenset({'ayam', 'krim '}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'krim '}), items_add=frozenset({'ayam'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'rempah-rempah', 'daging sapi giling'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'rempah-rempah'}), items_add=frozenset({'daging sapi giling'}), confidence=0.3234501347708895, lift=3.2919938411349285)]),
#  RelationRecord(items=frozenset({'saus tomat', 'daging sapi giling'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'saus tomat'}), items_add=frozenset({'daging sapi giling'}), confidence=0.3773584905660377, lift=3.840659481324083)]),
#  RelationRecord(items=frozenset({'daging tanpa tulang', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'daging tanpa tulang'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
#  RelationRecord(items=frozenset({'saus krim jamur', 'daging tanpa tulang'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'saus krim jamur'}), items_add=frozenset({'daging tanpa tulang'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'fromage blanc', 'madu'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'fromage blanc'}), items_add=frozenset({'madu'}), confidence=0.2450980392156863, lift=5.164270764485569)]),
#  RelationRecord(items=frozenset({'krim ', 'minyak zaitun'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'krim '}), items_add=frozenset({'minyak zaitun'}), confidence=0.20512820512820515, lift=3.1147098515519573)]),
#  RelationRecord(items=frozenset({'pasta gandum', 'minyak zaitun'}), support=0.007998933475536596, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta gandum'}), items_add=frozenset({'minyak zaitun'}), confidence=0.2714932126696833, lift=4.122410097642296)]),
#  RelationRecord(items=frozenset({'udang', 'pasta'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'udang'}), confidence=0.3220338983050847, lift=4.506672147735896)])]

# %%
def inspect(rslt):
    left_handSide    = [tuple(result[2][0][0])[0] for result in rslt] 
    right_handSide   = [tuple(result[2][0][1])[0] for result in rslt] 
    supports         = [result[1] for result in rslt]
    return list(zip(left_handSide,right_handSide, supports))
rslt_DataFrame = pd.DataFrame(inspect(rslt), columns = ['Produk 1', 'Produk 2', 'Support'])

# %%
rslt_DataFrame.nlargest(n = 7, columns = 'Support')
# Out:
#           Produk 1             Produk 2   Support
# 1    rempah-rempah   daging sapi giling  0.015998
# 7     pasta gandum        minyak zaitun  0.007999
# 3            pasta  daging tanpa tulang  0.005866
# 4  saus krim jamur  daging tanpa tulang  0.005733
# 2       saus tomat   daging sapi giling  0.005333
# 8            pasta                udang  0.005066
# 0            krim                  ayam  0.004533
