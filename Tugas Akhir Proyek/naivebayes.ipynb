# %%
#Import Library yang dibutuhkan
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-439b31db-cc30-4cc1-9bf2-327f521486f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-439b31db-cc30-4cc1-9bf2-327f521486f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Datasets.csv to Datasets.csv

# %%
data = pd.read_csv('Datasets.csv')
data.head()
# Out:
#                    Nama    NIS  Kelas  NRR B.Ind  NRR Agama  NRR PPKn  \
# 0        ADITYA NUGRAHA  16676  IPS 1         83         83        84
# 1      AL-FATH RAMADHAN  16644  IPS 1         82         85        83
# 2         ALKI EL RIDHO  16645  IPS 1         83         84        81
# 3  ANNISA AULIA SABRINA  16679  IPS 1         89         85        85
# 4     CICI JUANDA PUTRI  16683  IPS 1         83         85        80
#
#    NRR Matematika  NRR Sejarah  NRR Bahasa Inggris  NRR Seni Budaya  ...  \
# 0              82           78                  83               84  ...
# 1              83           83                  86               85  ...
# 2              82           78                  84               85  ...
# 3              84           82                  87               82  ...
# 4              82           78                  86               82  ...
#
#    USEK Matematika  USEK Sejarah  USEK B.Ing  USEK Senbud  USEK Penjaskes  \
# 0               74            84          87           82              88
# 1               88            89          89           88              90
# 2               83            83          90           84              87
# 3               83            88          73           85              85
# 4               82            85          85           89              86
#
#    USEK Prakarya  USEK Geografi  USEK Sosiologi  USEK Ekonomi  Status
# 0             82             87              86            88       T
# 1             88             88              90            84       L
# 2             84             90              85            85       L
# 3             87             74              85            73       T
# 4             88             82              84            85       L
#
# [5 rows x 28 columns]

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['Status']= label_encoder.fit_transform(data['Status'])
data['Status'].unique()
# Out:
# array([1, 0])

# %%
#dependence variable
X = data.iloc[:, 3:27].values 
#independence variable
y = data.iloc[:, 27].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
plt.scatter(X_train[:,0], X_train[:, 1], c=y_train, cmap='viridis')

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
y_pred = classifier.predict(X_test)
acc = metrics.accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import confusion_matrix
import pickle
cm = confusion_matrix(y_test, y_pred)
print("Confusin Matrix")
print(cm)

sns.heatmap(cm, annot=True, xticklabels=["Lulus","Tidak Lulus"],yticklabels=["Lulus","Tidak Lulus"])
print(f" Test Set: {len(X_test)}")
print(f" Accuracy = {acc*100} %")
# Out:
# Confusin Matrix
# [[30  3]
#  [ 2  5]]
#  Test Set: 40
#  Accuracy = 87.5 %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.92        33
#            1       0.62      0.71      0.67         7
#
#     accuracy                           0.88        40
#    macro avg       0.78      0.81      0.79        40
# weighted avg       0.88      0.88      0.88        40
